# %% [markdown]
# # Data Science I Topic 1 - Python Basic

# %% [markdown]
# ## Hello Python!

# %% [markdown]
# **Jupyter Notebook Tips**
#
# Only if editing with Colab, [Ctrl+M] is needed and Esc to get out of the cell is usually not necessary. For Mac, replace Ctrl with Cmd: <br>
# * (Esc) [Ctrl+M] A to insert cell above
# * (Esc) [Ctrl+M] B to insert cell below
# * (Esc) DD to delete selected cell - Colab:  [Ctrl+M] D
# * Enter to enter edit mode
# * Ctrl-Enter to run cell
# * Shift-Enter to run cell+select below
# * Alt-Enter to run cell+insert below
# * (Esc) [Ctrl+M] Y to change the cell to Code
# * (Esc) [Ctrl+M] M to change the cell to Markdown
#
#
# <u>Try out the instructions below, run the cells and inspect the results.</u>

# %%
# Try print('yourname') here
print('Tami')
# Out:
# Tami

# %% [markdown]
# ## Variables

# %% [markdown]
# <u>Run the cells below.</u>

# %%
x = 1000
type(x)
# Out:
# int

# %% [markdown]
# <u>Be careful with "." and ","</u>

# %%
y = 1.5
type(y)
# Out:
# float

# %%
z = 1,5
type(z)
# Out:
# tuple

# %%
upgrade = False
type(upgrade)
# Out:
# bool

# %%
message = 'Yes'
type(message)
# Out:
# str

# %% [markdown]
# ## Arithmetic operations

# %%
# Try addition, subtraction, multiplication, division
print(1+2)
print(1-2)
print(1*2)
print(1/2)
# Out:
# 3
# -1
# 2
# 0.5

# %%
# Try exponentiation with ** operator
# (Note that ^ in Python is bitwise XOR)
print(1**1)
print(1^1) # 1 XOR 1
# Out:
# 1
# 0

# %%
# Try Modulo with % operator
# a mod b = r, where a dividend, b divisor/modulus, and r remainder
# e.g. 1 mod 2 = 1
1%2
# Out:
# 1

# %% [markdown]
# ## Comparison operators

# %% [markdown]
# ### Equality

# %% [markdown]
# <u>Run the cells below and inspect the results.</u>

# %%
# Comparison of booleans
print(True == False)
# Out:
# False

# %%
# Comparison of integers
print((-5*5)!=25)
# Out:
# True

# %%
# Comparison of strings
print('name'=='Name')
# Out:
# False

# %%
# Compare a boolean with an integer
print(True==1)
print(False==0)
# Out:
# True
# True

# %% [markdown]
# ### Greater and less than

# %% [markdown]
# <u>Run the cells and inspect the results</u>

# %%
# Comparison of integers
x = (-3)**2
print(x >= 8)

x = -3**2
print(x >= 8)

# parentheses matter!
# Out:
# True
# False

# %%
# Comparison of strings
print('name'>'nam')
print('name'>'Name')
# Out:
# True
# True

# %%
# Comparison of booleans
print(True > False)
print(True <= False)
# Out:
# True
# False

# %% [markdown]
# ## Boolean operators

# %% [markdown]
# ### and, or, not

# %% [markdown]
# <u>Run the cells and inspect the results</u>

# %%
a = 14
b = 15

print(a>13 and b>13)
print(a>13 & b>13)
print((a>13) & (b>13))
# Out:
# True
# False
# True

# %%
print(a>13 or b>13)
print(a>13 | b>13)
print((a>13) | (b>13))
# Out:
# True
# False
# True

# %%
print(not(a!=13.0))
# Out:
# False

# %% [markdown]
# <u>Can you find out why "a>13 & b>13" and "(a>13) & (b>13)" gave different results? likewise with the operator "|".</u>

# %% [markdown]
# **Ans**:
#
# The operator `&` is the bitwise AND, while `and` is the logical AND.
#
# [Operator precedence](https://www.mathcs.emory.edu/~valerie/courses/fall10/155/resources/op_precedence.html)
#
# So "13 & b" and "13 | b" are executed first (bitwise).
#
# Since `&` is a bitwise AND operator, 13 and 15 are converted to binaries first:
# 1101 AND 1111 = 1101 (13)
#
# Then the statement a>13 & b>13 becomes a>13>13, executed from left to right: True>13 = False.
#
# Likewise: for bitwise OR `|`, 1101 OR 1111 = 1111 (15), then the statement a>13 | b>13 becomes a>15>13 which becomes False>13, which is False.

# %% [markdown]
# <u>Check if either a or b is an odd number.</u>

# %%
print(a%2==1 or b%2==1)
print((a%2==1) | (b%2==1))
# Out:
# True
# True

# %% [markdown]
# ## String concatenation

# %% [markdown]
# <u>Run the cells</u>

# %%
x = 500
y = 0.1
print("I'm starting with " + str(x) + ' Eur in my savings.'
    +' Somehow I could grow my savings by '+ str(y) + ' times'
       +' every month.' )
# Out:
# I'm starting with 500 Eur in my savings.
#  Somehow I could grow my savings by 0.1 times every month.

# %% [markdown]
# <u>Here we cast an integer to a string using str(), and concatenate series of strings by using '+' operator.
#
# Notice the \ to continue in a new line.</u>

# %% [markdown]
# ### Using `.format()`

# %%
print('I started with {} Eur in my savings. Somehow I could grow my savings by {} times every month.'.format(x,y) )
# Out:
# I started with 500 Eur in my savings. Somehow I could grow my savings by 0.1 times every month.

# %%
# Addition: if we use names in {}, we can change the order of the arguments in .format()
print('I started with {i} Eur in my savings. Somehow I could grow my savings by {j} times every month.'.format(j=y, i=x) )

# %% [markdown]
# <u>Continue the sentence, "After 12 months, I will have ... in my bank account."</u>

# %%
# calculate your saving after 12 months
z = x*(1+y)**12
print('After 12 months, I will have {} in my bank account.'.format(round(z,2)))
# Out:
# After 12 months, I will have 1569.21 in my bank account.

# %% [markdown]
# ### Using `f`-string
#
# <u>F-strings provide a way to embed expressions inside string literals, using a minimal syntax.In Python source code, an f-string is a literal string, prefixed with ‘f’, which contains expressions inside braces '{' and '}'. The expressions are replaced with their values.</u>

# %%
from datetime import datetime
import datetime
name = "Jasmine"
age = 26
birthday = datetime.date(1997, 3, 27)
res=f"My name is {name}, I am {age}, my birthday is {birthday:%A, %B %d, %Y}."
print(res)
# Out:
# My name is Jasmine, I am 26, my birthday is Thursday, March 27, 1997.

# %% [markdown]
# <u>Multirows</u>

# %%
major = "computer engineering"
hobby = "painting"
message = f"""
    Hi {name}.
    You are studying {major}.
    Your hobby is {hobby}.
 """
print(message)

# %% [markdown]
# ## If-elif-else

# %% [markdown]
# <u>You've seen the example of using If-elif-else in the lecture.
#
# Try it: use `z` value above.
# If `z`>1600, print "Definitely". If `z` is between 1200 and 1600, print "Maybe..", and if `z` is below 1200, print "Let's wait a couple more months".

# %%
print('Should I upgrade my PC?\n')

if z>1600:
  print("Definitely")
elif 1200 < z <= 1600: # Or elif z>1200:
  print("Maybe..")
else:
  print("Let's wait a couple more months")
# Out:
# Should I upgrade my PC?
#
# Maybe..

# %% [markdown]
# ## Loop

# %% [markdown]
# ### While Loop

# %% [markdown]
# <u>Produce a multiplication table of 7, from 1 to 5</u>
#
# 1 x 7 = 7 <br>
# ...<br>
# 5 x 7 = 35
#
# <u>using while loop and .format() in the string.</u>

# %%
x = 1
while x<6 :
    print(f'{x} x 7 = {x*7}')
    x = x+1
# Out:
# 1 x 7 = 7
# 2 x 7 = 14
# 3 x 7 = 21
# 4 x 7 = 28
# 5 x 7 = 35

# %% [markdown]
# ### For loop

# %% [markdown]
# <u>The same question (a multiplication table of 7, from 1 to 5), but with for loop.</u>

# %%
for x in range(1,6):
    print(f'{x} x 7 = {x*7}')
# Out:
# 1 x 7 = 7
# 2 x 7 = 14
# 3 x 7 = 21
# 4 x 7 = 28
# 5 x 7 = 35
